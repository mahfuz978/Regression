# %% [markdown]
# <a href="https://colab.research.google.com/github/mahfuz978/TECH-I.S---Regression-Classification/blob/main/Linear_Regression/Mahfuzur_Rahman_step_3_1_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style = 'white', color_codes = True)

# %%
# Data Acquisiton (Displaying of house dataset)
train  = pd.read_csv('https://raw.githubusercontent.com/Tech-i-s/data-science-course-wiki/master/Step%203-1%20Linear%20Regression/train.csv?token=AM2M2N5YGTBFGYDD3QH5FETAEWCB2')

# %%
test = pd.read_csv('https://raw.githubusercontent.com/Tech-i-s/data-science-course-wiki/master/Step%203-1%20Linear%20Regression/test.csv?token=AM2M2N3ERPI7CBPZX2MJMCLAEWCE4')

# %%
data = pd.concat([train, test], ignore_index = True)

# %%
train.shape
# Out:
# (1460, 81)

# %%
test.shape
# Out:
# (1459, 80)

# %%
data.shape
# Out:
# (2919, 81)

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  ...  YrSold  SaleType SaleCondition
# 0  1461          20       RH  ...    2010        WD        Normal
# 1  1462          20       RL  ...    2010        WD        Normal
# 2  1463          60       RL  ...    2010        WD        Normal
# 3  1464          60       RL  ...    2010        WD        Normal
# 4  1465         120       RL  ...    2010        WD        Normal
#
# [5 rows x 80 columns]

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal  208500.0
# 1   2          20       RL  ...        WD         Normal  181500.0
# 2   3          60       RL  ...        WD         Normal  223500.0
# 3   4          70       RL  ...        WD        Abnorml  140000.0
# 4   5          60       RL  ...        WD         Normal  250000.0
#
# [5 rows x 81 columns]

# %%
df = data.select_dtypes(include = ['float64', 'int64'])
df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  ...  MiscVal  MoSold  YrSold  SalePrice
# 0   1          60         65.0     8450  ...        0       2    2008   208500.0
# 1   2          20         80.0     9600  ...        0       5    2007   181500.0
# 2   3          60         68.0    11250  ...        0       9    2008   223500.0
# 3   4          70         60.0     9550  ...        0       2    2006   140000.0
# 4   5          60         84.0    14260  ...        0      12    2008   250000.0
#
# [5 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Data columns (total 38 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   LotFrontage    2433 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   OverallQual    2919 non-null   int64
#  5   OverallCond    2919 non-null   int64
#  6   YearBuilt      2919 non-null   int64
#  7   YearRemodAdd   2919 non-null   int64
#  8   MasVnrArea     2896 non-null   float64
#  9   BsmtFinSF1     2918 non-null   float64
#  10  BsmtFinSF2     2918 non-null   float64
#  11  BsmtUnfSF      2918 non-null   float64
#  12  TotalBsmtSF    2918 non-null   float64
#  13  1stFlrSF       2919 non-null   int64
#  14  2ndFlrSF       2919 non-null   int64
#  15  LowQualFinSF   2919 non-null   int64
#  16  GrLivArea      2919 non-null   int64
#  17  BsmtFullBath   2917 non-null   float64
#  18  BsmtHalfBath   2917 non-null   float64
#  19  FullBath       2919 non-null   int64
#  20  HalfBath       2919 non-null   int64
#  21  BedroomAbvGr   2919 non-null   int64
#  22  KitchenAbvGr   2919 non-null   int64
#  23  TotRmsAbvGrd   2919 non-null   int64
#  24  Fireplaces     2919 non-null   int64
#  25  GarageYrBlt    2760 non-null   float64
#  26  GarageCars     2918 non-null   float64
#  27  GarageArea     2918 non-null   float64
#  28  WoodDeckSF     2919 non-null   int64
#  29  OpenPorchSF    2919 non-null   int64
#  30  EnclosedPorch  2919 non-null   int64
#  31  3SsnPorch      2919 non-null   int64
#  32  ScreenPorch    2919 non-null   int64
#  33  PoolArea       2919 non-null   int64
#  34  MiscVal        2919 non-null   int64
#  35  MoSold         2919 non-null   int64
#  36  YrSold         2919 non-null   int64
#  37  SalePrice      1460 non-null   float64
# dtypes: float64(12), int64(26)
# memory usage: 866.7 KB

# %%
df.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  2919.000000  2919.000000  ...  2919.000000    1460.000000
# mean   1460.000000    57.137718  ...  2007.792737  180921.195890
# std     842.787043    42.517628  ...     1.314964   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     730.500000    20.000000  ...  2007.000000  129975.000000
# 50%    1460.000000    50.000000  ...  2008.000000  163000.000000
# 75%    2189.500000    70.000000  ...  2009.000000  214000.000000
# max    2919.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
# identify missing values
miss_val = df.isna().sum()
miss_val
# Out:
# Id                  0
# MSSubClass          0
# LotFrontage       486
# LotArea             0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# MasVnrArea         23
# BsmtFinSF1          1
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        2
# BsmtHalfBath        2
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# TotRmsAbvGrd        0
# Fireplaces          0
# GarageYrBlt       159
# GarageCars          1
# GarageArea          1
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# MiscVal             0
# MoSold              0
# YrSold              0
# SalePrice        1459
# dtype: int64

# %%
# sorting missing values
miss_val[miss_val>0].sort_values(ascending = False)
# Out:
# SalePrice       1459
# LotFrontage      486
# GarageYrBlt      159
# MasVnrArea        23
# BsmtHalfBath       2
# BsmtFullBath       2
# GarageArea         1
# GarageCars         1
# TotalBsmtSF        1
# BsmtUnfSF          1
# BsmtFinSF2         1
# BsmtFinSF1         1
# dtype: int64

# %%
columns = ['LotFrontage','GarageYrBlt','MasVnrArea','BsmtHalfBath','BsmtFullBath','GarageArea','GarageCars','TotalBsmtSF',\
                'BsmtUnfSF','BsmtFinSF2','BsmtFinSF1']
for x in columns:
  df[x] = df[x].fillna(df[x].mean())

# %%
df.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# LotFrontage         0
# LotArea             0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# MasVnrArea          0
# BsmtFinSF1          0
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# TotRmsAbvGrd        0
# Fireplaces          0
# GarageYrBlt         0
# GarageCars          0
# GarageArea          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# MiscVal             0
# MoSold              0
# YrSold              0
# SalePrice        1459
# dtype: int64

# %%
# Showing overview of the train dataset after imputing missing values
df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  ...  MiscVal  MoSold  YrSold  SalePrice
# 0   1          60         65.0     8450  ...        0       2    2008   208500.0
# 1   2          20         80.0     9600  ...        0       5    2007   181500.0
# 2   3          60         68.0    11250  ...        0       9    2008   223500.0
# 3   4          70         60.0     9550  ...        0       2    2006   140000.0
# 4   5          60         84.0    14260  ...        0      12    2008   250000.0
#
# [5 rows x 38 columns]

# %%
df.shape
2919/2
# Out:
# 1459.5

# %%
df_train = df[:1460]
df_test = df[1460:]

# %%
data_corr = df_train.corr()
data_corr
# Out:
#                      Id  MSSubClass  LotFrontage  ...    MoSold    YrSold  SalePrice
# Id             1.000000    0.011156    -0.009828  ...  0.021172  0.000712  -0.021917
# MSSubClass     0.011156    1.000000    -0.356828  ... -0.013585 -0.021407  -0.084284
# LotFrontage   -0.009828   -0.356828     1.000000  ...  0.010366  0.006494   0.334820
# LotArea       -0.033226   -0.139781     0.305194  ...  0.001205 -0.014261   0.263843
# OverallQual   -0.028365    0.032628     0.234641  ...  0.070815 -0.027347   0.790982
# OverallCond    0.012609   -0.059316    -0.053148  ... -0.003511  0.043950  -0.077856
# YearBuilt     -0.012713    0.027850     0.116955  ...  0.012398 -0.013618   0.522897
# YearRemodAdd  -0.021998    0.040581     0.083176  ...  0.021490  0.035743   0.507101
# MasVnrArea    -0.050212    0.022905     0.179112  ... -0.005951 -0.008186   0.475210
# BsmtFinSF1    -0.005024   -0.069836     0.214800  ... -0.015727  0.014359   0.386420
# BsmtFinSF2    -0.005968   -0.065649     0.042720  ... -0.015211  0.031706  -0.011378
# BsmtUnfSF     -0.007940   -0.140759     0.123537  ...  0.034888 -0.041258   0.214479
# TotalBsmtSF   -0.015415   -0.238518     0.363451  ...  0.013196 -0.014969   0.613581
# 1stFlrSF       0.010496   -0.251758     0.413931  ...  0.031372 -0.013604   0.605852
# 2ndFlrSF       0.005590    0.307886     0.072418  ...  0.035164 -0.028700   0.319334
# LowQualFinSF  -0.044230    0.046474     0.037290  ... -0.022174 -0.028921  -0.025606
# GrLivArea      0.008273    0.074853     0.368132  ...  0.050240 -0.036526   0.708624
# BsmtFullBath   0.002289    0.003491     0.090677  ... -0.025361  0.067049   0.227122
# BsmtHalfBath  -0.020155   -0.002333    -0.006816  ...  0.032873 -0.046524  -0.016844
# FullBath       0.005587    0.131608     0.180508  ...  0.055872 -0.019669   0.560664
# HalfBath       0.006784    0.177354     0.047525  ... -0.009050 -0.010269   0.284108
# BedroomAbvGr   0.037719   -0.023438     0.236901  ...  0.046544 -0.036014   0.168213
# KitchenAbvGr   0.002951    0.281721    -0.005167  ...  0.026589  0.031687  -0.135907
# TotRmsAbvGrd   0.027239    0.040380     0.320421  ...  0.036907 -0.034516   0.533723
# Fireplaces    -0.019772   -0.045569     0.233967  ...  0.046357 -0.024096   0.466929
# GarageYrBlt    0.000121    0.079867     0.064719  ...  0.005244 -0.001029   0.471062
# GarageCars     0.016570   -0.040110     0.269604  ...  0.040522 -0.039117   0.640409
# GarageArea     0.017634   -0.098672     0.323566  ...  0.027974 -0.027378   0.623431
# WoodDeckSF    -0.029643   -0.012579     0.076000  ...  0.021011  0.022270   0.324413
# OpenPorchSF   -0.000477   -0.006100     0.137147  ...  0.071255 -0.057619   0.315856
# EnclosedPorch  0.002889   -0.012037     0.010143  ... -0.028887 -0.009916  -0.128578
# 3SsnPorch     -0.046635   -0.043825     0.062061  ...  0.029474  0.018645   0.044584
# ScreenPorch    0.001330   -0.026030     0.037665  ...  0.023217  0.010694   0.111447
# PoolArea       0.057044    0.008283     0.180839  ... -0.033737 -0.059689   0.092404
# MiscVal       -0.006242   -0.007683     0.000159  ... -0.006495  0.004906  -0.021190
# MoSold         0.021172   -0.013585     0.010366  ...  1.000000 -0.145721   0.046432
# YrSold         0.000712   -0.021407     0.006494  ... -0.145721  1.000000  -0.028923
# SalePrice     -0.021917   -0.084284     0.334820  ...  0.046432 -0.028923   1.000000
#
# [38 rows x 38 columns]

# %%
#considering only the features which have absolute correlation value greater tha 0.60
data_corr = data_corr['SalePrice'][:-1]
data_corr[abs(data_corr)>=0.60].sort_values(ascending = False)
# Out:
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# TotalBsmtSF    0.613581
# 1stFlrSF       0.605852
# Name: SalePrice, dtype: float64

# %%
# df_test.drop(['SalePrice'],axis = 1, inplace = True)
df_train = df_train[['OverallQual','GrLivArea','GarageCars','GarageArea','TotalBsmtSF','1stFlrSF','SalePrice']]
df_test = df_test[['OverallQual','GrLivArea','GarageCars','GarageArea','TotalBsmtSF','1stFlrSF']]

# %%
df_train.head()
# Out:
#    OverallQual  GrLivArea  GarageCars  ...  TotalBsmtSF  1stFlrSF  SalePrice
# 0            7       1710         2.0  ...        856.0       856   208500.0
# 1            6       1262         2.0  ...       1262.0      1262   181500.0
# 2            7       1786         2.0  ...        920.0       920   223500.0
# 3            7       1717         3.0  ...        756.0       961   140000.0
# 4            8       2198         3.0  ...       1145.0      1145   250000.0
#
# [5 rows x 7 columns]

# %%
corr = df_train.corr()
plt.figure(figsize=(5,5))
sns.heatmap(corr, annot = True, cmap = 'cubehelix_r', square = True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
train, val = train_test_split(df_train, test_size = 0.25)

# %%
#considering only the highly correlated features for training and validation
train_x = train.drop(['SalePrice'], axis = 1)
train_y = train['SalePrice']   # output of the training data
val_x = val.drop(['SalePrice'], axis = 1)
val_y = val['SalePrice']

# %%
print('Dimension of train_x dataframe:',train_x.shape)
print('Dimension of train_y dataframe:',train_y.shape)
print('Dimension of val_x dataframe:',val_x.shape)
print('Dimension of val_y dataframe:',val_y.shape)
# Out:
# Dimension of train_x dataframe: (1095, 6)
# Dimension of train_y dataframe: (1095,)
# Dimension of val_x dataframe: (365, 6)
# Dimension of val_y dataframe: (365,)

# %%
from sklearn.linear_model import LinearRegression
ln_reg  = LinearRegression()
ln_reg.fit(train_x, train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
df_pred =ln_reg.predict(val_x)
print('Mean Absolute Error of linear regression:',mean_absolute_error(df_pred, val_y))
print('Mean Square Error of linear regression:', mean_squared_error(df_pred, val_y))
print('R_Squared Score of linear regression:', r2_score(df_pred, val_y))
# Out:
# Mean Absolute Error of linear regression: 27226.473566488377
# Mean Square Error of linear regression: 2386922178.935323
# R_Squared Score of linear regression: 0.5785416392904167

# %%
#final prediction on test data

predict_test = ln_reg.predict(df_test)

# %%
#Create Sample Submission file 
submission_data = pd.DataFrame({'Id': test.Id, 'Pred_SalePrice': predict_test})
submission_data
pred = pd.DataFrame(val_y)
pred['Predicted'] = submission_data['Pred_SalePrice']
pred
# Out:
#       SalePrice      Predicted
# 543    133000.0  259134.513645
# 322    301000.0  142444.967661
# 478    297000.0  259958.351277
# 953    172000.0  122297.581432
# 500    113000.0  123315.098242
# ...         ...            ...
# 819    224000.0   85461.908008
# 1007    88000.0  108188.183825
# 1029   118000.0  131734.736635
# 988    195000.0  124813.005813
# 1063   110500.0  128176.494467
#
# [365 rows x 2 columns]

# %%
from sklearn.linear_model import Ridge, Lasso
ridge = Ridge()
ridge
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
ridge.fit(train_x, train_y)
ridge_score = ridge.score(val_x, val_y)
coeff_used = np.sum(ridge.coef_ != 0)
print(f'training score is {ridge_score}')
print(f'number of feature used is {coeff_used}')
# Out:
# training score is 0.680333392721349
# number of feature used is 6

# %%
lasso = Lasso()
lasso.fit(train_x, train_y)
lasso_score = lasso.score(val_x, val_y)
coeff_used = np.sum(lasso.coef_ != 0)
print(f'training score is {lasso_score}')
print(f'number of feature used is {coeff_used}')
# Out:
# training score is 0.6804314200952843
# number of feature used is 6
